# %%
import sys
sys.path.append('/Users/mnannan/dev/supelec/ngsa/assignments/Assignement 2 ')

# %%
from core.io.loader import *

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = get_data_with_node_information('train', data_dir='../data')

# %% [markdown]
# ### Same journal

# %%
train['same_journal'] = (train.source_journal == train.target_journal)

# %%
train[['source_id', 'source_journal']].drop_duplicates('source_id')\
.groupby('source_journal').count().sort_values('source_id', ascending=False)
# Out:
#                                     source_id
# source_journal
# Phys.Lett.                               3575
# Nucl.Phys.                               3571
# Phys.Rev.                                3170
# JHEP                                     1957
# Int.J.Mod.Phys.                           938
# Mod.Phys.Lett.                            936
# Class.Quant.Grav.                         556
# J.Phys.                                   536
# J.Math.Phys.                              532
# Phys.Rev.Lett.                            388
# Phys.                                     377
# Commun.Math.Phys.                         377
# Nucl.Phys.Proc.Suppl.                     296
# Prog.Theor.Phys.                          281
# Nucl.                                     240
# Annals                                    207
# Lett.Math.Phys.                           167
# Mod.                                      134
# Fortsch.Phys.                             132
# ...

# %%
def extract_journal_overlaping(journal1, journal2):
    if journal1 and journal2:
        journal1.split('.')
extract_journal_overlaping('Phys.Lett.', 'Nucl.Phys.')

# %%
train.source_journal.
# Out:
# 0                     Phys.Lett.
# 510736                   Z.Phys.
# 451434                Nucl.Phys.
# 168455           Int.J.Mod.Phys.
# 170930            Mod.Phys.Lett.
# 21430                 Phys.Lett.
# 426916            Mod.Phys.Lett.
# 201084            Mod.Phys.Lett.
# 167792                Nucl.Phys.
# 192101                Nucl.Phys.
# 126225               Eur.Phys.J.
# 514327                       NaN
# 222625                       NaN
# 486060                Nucl.Phys.
# 484078            Mod.Phys.Lett.
# 411789                Phys.Lett.
# 28303             Phys.Rev.Lett.
# 513109                Nucl.Phys.
# 448365                 Phys.Rev.
# 561330                 Phys.Rev.
# 19890                 Phys.Lett.
# 97855                  Phys.Rev.
# 211853                Phys.Lett.
# 474747                       NaN
# 460802                     Nucl.
# 431055                       NaN
# 336699                       NaN
# 481502                Phys.Lett.
# ...

# %%
p = train.source_journal

# %%
p.drop_duplicates().tolist()
# Out:
# ['Phys.Lett.',
#  'Z.Phys.',
#  'Nucl.Phys.',
#  'Int.J.Mod.Phys.',
#  'Mod.Phys.Lett.',
#  'Eur.Phys.J.',
#  nan,
#  'Phys.Rev.Lett.',
#  'Phys.Rev.',
#  'Nucl.',
#  'JHEP',
#  'Prog.Theor.Phys.',
#  'Commun.Math.Phys.',
#  'Adv.Theor.Math.Phys.',
#  'Math.Methods',
#  'AIP',
#  'Annals',
#  'Class.Quant.Grav.',
#  'Nucl.Phys.Proc.Suppl.',
#  'Europhys.Lett.',
#  'Grav.Cosmol.',
#  'Annales',
#  'Phys.Rept.',
#  'Class.',
#  'J.Phys.',
#  'Lett.Math.Phys.',
#  'Annalen',
#  'J.Geom.Phys.',
#  'Teor.Mat.Fiz.',
#  'Phys.',
#  'Lett.',
#  'Theor.Math.Phys.',
#  'J.Math.Phys.',
#  'J.Statist.Phys.',
#  'Chin.Phys.Lett.',
#  'Int.',
#  'Mod.',
#  'Aport.',
#  'Fizika',
#  'JETP',
#  'Speculations',
#  'Rev.Mod.Phys.',
#  'Surveys',
#  'Gen.Rel.Grav.',
#  'Int.J.Theor.Phys.',
#  'Lect.Notes',
#  'Rom.J.Phys.',
#  'Ann.',
#  'Helv.Phys.Acta',
#  'Fortsch.Phys.',
#  'J.Korean',
#  'Published',
#  'Phys.Part.Nucl.',
#  'Prog.Theor.Phys.Suppl.',
#  'Math-Physics-Astronomy',
#  'Phys.Usp.',
# ...
